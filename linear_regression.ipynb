# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from linear_regression import LinearRegression

# %%
df = pd.read_csv('./test.csv')

# %%
df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
plt.scatter(df["x"], df["y"])

# %%
linear_regression = LinearRegression(x_feature = df["x"], y_target = df["y"])

# %%
linear_regression.gradient_descent()
# Out:
# (np.float64(1.007243073320577), np.float64(0.012165688035283652))

# %%
plt.plot(linear_regression.weights, linear_regression.costs)
plt.scatter(linear_regression.weights, linear_regression.costs)

# %%
y_predicted = linear_regression.predict()

# %%
y_predicted
# Out:
# 0      77.569882
# 1      21.164270
# 2      22.171513
# 3      20.157027
# 4      36.272916
#          ...
# 295    71.526424
# 296    46.345347
# 297    55.410535
# 298    62.461236
# 299    47.352590
# Name: x, Length: 300, dtype: float64

# %%
plt.scatter(df['x'], df['y'], marker='o', color='red')
plt.plot(df["x"], y_predicted)
